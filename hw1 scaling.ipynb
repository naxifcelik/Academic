# %%
import cv2 as cv
import os
import random
import shutil
import numpy as np
#\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/
#                          Nazif ÇELİK 090200712                        #
#\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/\/

# %%
renkliaraba = "C:\\Users\\n\\images\\car"
renkliucak = "C:\\Users\\n\\Desktop\\images\\Flugzeug"
scaledaraba = "C:\\Users\\n\\images\\car_labelled"
scaleducak = "C:\\Users\\n\\images\\sonucak"

# %%
image_number = 0
while image_number<500:   
    random_image=random.choice(os.listdir(renkliaraba))
    source_file = os.path.join(renkliaraba,random_image)
    image_number+=1

# %%
for f in os.listdir(scaledaraba):
    filename=os.path.join(scaledaraba,f)
    image = cv.imread(filename) 
    image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)      
    image = cv.resize(image, (100,100), interpolation = cv.INTER_AREA)
    image = cv.imwrite(filename,image)

# %%
image_number = 0
while image_number<500:   
    random_image=random.choice(os.listdir(renkliucak))
    source_file = os.path.join(renkliucak,random_image)
    image_number+=1

# %%
for f in os.listdir(scaleducak):
    filename=os.path.join(scaleducak,f)
    image = cv.imread(filename) 
    image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)      
    image = cv.resize(image, (100,100), interpolation = cv.INTER_AREA)
    image = cv.imwrite(filename,image)
    print (type(image))
# Out:
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# ...
